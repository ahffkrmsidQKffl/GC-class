# %% [markdown]
# # 웰치-포웰 알고리즘 실습 프로그램
# ### [예제 7-21]

# %%
# 그래프 객체를 나타내는 클래스
class Graph:
    def __init__(self, edges, n):
        self.adjList = [[] for _ in range(n)]
        
        for (src, dest) in edges:
            self.adjList[src].append(dest)
            self.adjList[dest].append(src)


# 그래프 그리기
def makeGraph(V, E):
    import networkx as nx
    import matplotlib.pyplot as plt
    G = nx.Graph()
    G.add_nodes_from(V)
    G.add_edges_from(E) 
    
    result = {}
 
    # 정점에 하나씩 색상 할당
    for u in range(vertex):
 
        # `u` 인접 정점의 색상 확인 후 집합에 저장
        assigned = set([result.get(i) for i in graph.adjList[u] if i in result])
 
        color = 1
        for c in assigned:
            if color != c:
                break
            color = color + 1
 
        # 정점 `u`에 사용 가능한 첫 번째 색상 할당
        result[u] = color
    
    colors = ['', 'BLUE', 'GREEN', 'RED', 'YELLOW', 'ORANGE', 'PINK',
            'BLACK', 'BROWN', 'WHITE', 'PURPLE', 'VOILET']
    colors_map = []
    for v in range(vertex):
        colors_map.append(colors[result[v]])
    
    nx.draw(G, with_labels=True,
        node_color=colors_map,
        node_size=1000,
        width=4,
        font_size=22, alpha=0.8)
    plt.show()


# 정점의 수와 간선 입력
vertex = 8
edges = {(0,1),(0,2),(0,3),(0,6),(1,2),(1,3),(1,4),(2,4),
     (2,5),(2,6),(3,4),(3,6),(4,5),(4,6),(4,7),(5,7),(6,7)}

V = {i for i in range(vertex)}
graph = Graph(edges, vertex)
makeGraph(V,edges)
