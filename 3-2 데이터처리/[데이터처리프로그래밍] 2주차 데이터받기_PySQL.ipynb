# %% [markdown]
# ###  파이썬을 이용한  데이터 소싱

# %%
pip install pandas-datareader
# Out:
# Collecting pandas-datareader
#   Downloading pandas_datareader-0.10.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: lxml in c:\users\tksmd\anaconda3\lib\site-packages (from pandas-datareader) (4.9.3)
# Requirement already satisfied: pandas>=0.23 in c:\users\tksmd\anaconda3\lib\site-packages (from pandas-datareader) (2.1.4)
# Requirement already satisfied: requests>=2.19.0 in c:\users\tksmd\anaconda3\lib\site-packages (from pandas-datareader) (2.31.0)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\tksmd\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tksmd\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tksmd\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\tksmd\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tksmd\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tksmd\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tksmd\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tksmd\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2024.2.2)
# Requirement already satisfied: six>=1.5 in c:\users\tksmd\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas-datareader) (1.16.0)
# Downloading pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
#    ---------------------------------------- 0.0/109.5 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/109.5 kB ? eta -:--:--
#    ------------------------------------- -- 102.4/109.5 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 109.5/109.5 kB 1.6 MB/s eta 0:00:00
# Installing collected packages: pandas-datareader
# Successfully installed pandas-datareader-0.10.0
# Note: you may need to restart the kernel to use updated packages.

# %%
#  from stooq

import pandas_datareader.data as web
import seaborn as sns
df = web.DataReader('^KOSPI', 'stooq')
print(df.head(10) )
sns.lineplot( data=df,x=df.index, y="Close")
# Out:
#                Open     High      Low    Close     Volume
# Date
# 2024-10-08  2592.65  2601.96  2581.79  2596.90  287832000
# 2024-10-07  2579.20  2611.93  2561.46  2610.38  343671000
# 2024-10-04  2563.70  2585.59  2555.57  2569.71  414329000
# 2024-10-02  2566.55  2590.88  2555.46  2561.69  351004000
# 2024-09-30  2665.24  2668.66  2593.27  2593.27  358916000
# 2024-09-27  2674.58  2681.45  2649.78  2649.78  413004000
# 2024-09-26  2630.91  2671.57  2630.30  2671.57  324889000
# 2024-09-25  2652.71  2663.36  2596.32  2596.32  454472000
# 2024-09-24  2612.45  2631.68  2597.90  2631.68  355097000
# 2024-09-23  2596.47  2603.57  2588.49  2602.01  339140000
# C:\Users\tksmd\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\tksmd\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Date', ylabel='Close'>

# %%
# from FRED

import pandas_datareader.data as web
import datetime

start = datetime.datetime(2015, 2, 1)
end = datetime.datetime(2024, 9, 5)

oil = web.DataReader('DCOILWTICO', 'fred', start, end)
print(oil)
sns.lineplot( data=oil,x=oil.index, y="DCOILWTICO")
# Out:
#             DCOILWTICO
# DATE
# 2015-02-02       49.25
# 2015-02-03       53.04
# 2015-02-04       48.45
# 2015-02-05       50.48
# 2015-02-06       51.66
# ...                ...
# 2024-08-30       74.52
# 2024-09-02         NaN
# 2024-09-03       71.28
# 2024-09-04       70.11
# 2024-09-05       70.09
#
# [2504 rows x 1 columns]
# C:\Users\tksmd\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\tksmd\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='DATE', ylabel='DCOILWTICO'>

# %%
pip install pykrx
# Out:
# Collecting pykrx
#   Downloading pykrx-1.0.48-py3-none-any.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.9 kB ? eta -:--:--
#      ------------------------------- ------ 51.2/60.9 kB 525.1 kB/s eta 0:00:01
#      -------------------------------------- 60.9/60.9 kB 539.2 kB/s eta 0:00:00
# Requirement already satisfied: requests in c:\users\tksmd\anaconda3\lib\site-packages (from pykrx) (2.31.0)
# Requirement already satisfied: pandas in c:\users\tksmd\anaconda3\lib\site-packages (from pykrx) (2.1.4)
# Collecting datetime (from pykrx)
#   Downloading DateTime-5.5-py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: numpy in c:\users\tksmd\anaconda3\lib\site-packages (from pykrx) (1.26.4)
# Collecting xlrd (from pykrx)
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Collecting deprecated (from pykrx)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: multipledispatch in c:\users\tksmd\anaconda3\lib\site-packages (from pykrx) (0.6.0)
# Requirement already satisfied: matplotlib in c:\users\tksmd\anaconda3\lib\site-packages (from pykrx) (3.8.0)
# Requirement already satisfied: zope.interface in c:\users\tksmd\anaconda3\lib\site-packages (from datetime->pykrx) (5.4.0)
# Requirement already satisfied: pytz in c:\users\tksmd\anaconda3\lib\site-packages (from datetime->pykrx) (2023.3.post1)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\tksmd\anaconda3\lib\site-packages (from deprecated->pykrx) (1.14.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tksmd\anaconda3\lib\site-packages (from matplotlib->pykrx) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\tksmd\anaconda3\lib\site-packages (from matplotlib->pykrx) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tksmd\anaconda3\lib\site-packages (from matplotlib->pykrx) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\tksmd\anaconda3\lib\site-packages (from matplotlib->pykrx) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\tksmd\anaconda3\lib\site-packages (from matplotlib->pykrx) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\tksmd\anaconda3\lib\site-packages (from matplotlib->pykrx) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\tksmd\anaconda3\lib\site-packages (from matplotlib->pykrx) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tksmd\anaconda3\lib\site-packages (from matplotlib->pykrx) (2.8.2)
# Requirement already satisfied: six in c:\users\tksmd\anaconda3\lib\site-packages (from multipledispatch->pykrx) (1.16.0)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\tksmd\anaconda3\lib\site-packages (from pandas->pykrx) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tksmd\anaconda3\lib\site-packages (from requests->pykrx) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tksmd\anaconda3\lib\site-packages (from requests->pykrx) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tksmd\anaconda3\lib\site-packages (from requests->pykrx) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tksmd\anaconda3\lib\site-packages (from requests->pykrx) (2024.2.2)
# Requirement already satisfied: setuptools in c:\users\tksmd\anaconda3\lib\site-packages (from zope.interface->datetime->pykrx) (68.2.2)
# Downloading pykrx-1.0.48-py3-none-any.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.2 MB 6.3 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.6/2.2 MB 5.8 MB/s eta 0:00:01
#    --------------- ------------------------ 0.9/2.2 MB 6.8 MB/s eta 0:00:01
#    -------------------- ------------------- 1.1/2.2 MB 6.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.2/2.2 MB 5.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.5/2.2 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.9/2.2 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------  2.2/2.2 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 5.8 MB/s eta 0:00:00
# Downloading DateTime-5.5-py3-none-any.whl (52 kB)
#    ---------------------------------------- 0.0/52.6 kB ? eta -:--:--
#    ---------------------------------------- 52.6/52.6 kB ? eta 0:00:00
# Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#    ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#    ---------------------------------------- 96.5/96.5 kB 5.4 MB/s eta 0:00:00
# Installing collected packages: xlrd, deprecated, datetime, pykrx
# Successfully installed datetime-5.5 deprecated-1.2.14 pykrx-1.0.48 xlrd-2.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# Finance-DataReader (국내 주가 데이터 받기)

from pykrx import stock
tickers=stock.get_market_ticker_list(market="KOSPI")

# %%
print(tickers[0:10])
# Out:
# ['095570', '006840', '027410', '282330', '138930', '001460', '001465', '001040', '079160', '00104K']

# %%
k_df =stock.get_market_ohlcv("20180101","20240905","005930","d",adjusted=True)  # 주기 m,y,d
k_df.tail(10)
# Out:
#                시가     고가     저가     종가       거래량       등락률
# 날짜
# 2024-08-23  77700  78400  77500  77700   9420306 -0.766284
# 2024-08-26  78100  78200  76000  76100  15655938 -2.059202
# 2024-08-27  75700  76500  75600  75800  11130145 -0.394218
# 2024-08-28  75800  76400  75400  76400   9794514  0.791557
# 2024-08-29  73600  74700  73500  74000  16884479 -3.141361
# 2024-08-30  74400  75000  74100  74300  16358520  0.405405
# 2024-09-02  74500  74700  73500  74400  12641376  0.134590
# 2024-09-03  74100  74300  72500  72500  16314599 -2.553763
# 2024-09-04  69800  71100  69800  70000  27366563 -3.448276
# 2024-09-05  70100  71200  69000  69000  25686769 -1.428571

# %%
sns.lineplot( data=k_df,x=k_df.index, y="종가")
# Out:
# C:\Users\tksmd\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\tksmd\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='날짜', ylabel='종가'>

# %%
# 파이썬에서 SQL DB에 접속하기

import pymysql

con = pymysql.connect(
    user='root',
    passwd='1234',
    host='127.0.0.1',
    db='example',
    charset='utf8'
)

mycursor=con.cursor()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[10], line 5
#       1 # 파이썬에서 SQL DB에 접속하기
#       3 import pymysql
# ----> 5 con = pymysql.connect(
#       6     user='root',
#       7     passwd='1234',
#       8     host='127.0.0.1',
#       9     db='example',
#      10     charset='utf8'
#      11 )
#      13 mycursor=con.cursor()
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:361, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, collation, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_key_password, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     359     self._sock = None
#     360 else:
# --> 361     self.connect()
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:669, in Connection.connect(self, sock)
#     666 self._next_seq_id = 0
#     668 self._get_server_information()
# --> 669 self._request_authentication()
#     671 # Send "SET NAMES" query on init for:
#     672 # - Ensure charaset (and collation) is set to the server.
#     673 #   - collation_id in handshake packet may be ignored.
#    (...)
#     682 # - https://github.com/wagtail/wagtail/issues/9477
#     683 # - https://zenn.dev/methane/articles/2023-mysql-collation (Japanese)
#     684 self.set_character_set(self.charset, self.collation)
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:979, in Connection._request_authentication(self)
#     977 # https://dev.mysql.com/doc/internals/en/successful-authentication.html
#     978 if self._auth_plugin_name == "caching_sha2_password":
# --> 979     auth_packet = _auth.caching_sha2_password_auth(self, auth_packet)
#     980 elif self._auth_plugin_name == "sha256_password":
#     981     auth_packet = _auth.sha256_password_auth(self, auth_packet)
#
# File ~\anaconda3\Lib\site-packages\pymysql\_auth.py:268, in caching_sha2_password_auth(conn, pkt)
#     265         print(conn.server_public_key.decode("ascii"))
#     267 data = sha2_rsa_encrypt(conn.password, conn.salt, conn.server_public_key)
# --> 268 pkt = _roundtrip(conn, data)
#
# File ~\anaconda3\Lib\site-packages\pymysql\_auth.py:121, in _roundtrip(conn, send_data)
#     119 def _roundtrip(conn, send_data):
#     120     conn.write_packet(send_data)
# --> 121     pkt = conn._read_packet()
#     122     pkt.check_error()
#     123     return pkt
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:775, in Connection._read_packet(self, packet_type)
#     773     if self._result is not None and self._result.unbuffered_active is True:
#     774         self._result.unbuffered_active = False
# --> 775     packet.raise_for_error()
#     776 return packet
#
# File ~\anaconda3\Lib\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     217 if DEBUG:
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File ~\anaconda3\Lib\site-packages\pymysql\err.py:150, in raise_mysql_exception(data)
#     148 if errorclass is None:
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# OperationalError: (1045, "Access denied for user 'root'@'localhost' (using password: YES)")

# %%
#  DB에 table 구축

import pandas as pd 
from sqlalchemy import create_engine 

# Create dataframe

df = pd.DataFrame(data=[ [111,'Jin','35','Korea'],
                         [222,'Ben',42,'Australia'],
                         [333,'Harry',28,'India'],
                         [444,'Joe',42,'Canada'],
                         [555,'Tim',28,'Jordan']],
                       columns=['id','name','age','country']) 
                       

# Create SQLAlchemy engine to connect to MySQL Database 

engine = create_engine('mysql+pymysql://root:1234@127.0.0.1:3306/example') 

df.to_sql('member', engine, index=False,if_exists='replace')
# Out:
# 5

# %%
#  example DB에서 member table 가져오기

query = """
    select  * from member;
"""
mb = pd.read_sql(query, con=engine)
engine.dispose()  


display(mb)
# Out:
#     id   name age    country
# 0  111    Jin  35      Korea
# 1  222    Ben  42  Australia
# 2  333  Harry  28      India
# 3  444    Joe  42     Canada
# 4  555    Tim  28     Jordan

# %%
df3=pd.read_sql_table('member', con=engine)
df3
# Out:
#     id   name age    country
# 0  111    Jin  35      Korea
# 1  222    Ben  42  Australia
# 2  333  Harry  28      India
# 3  444    Joe  42     Canada
# 4  555    Tim  28     Jordan

# %%
# 1. 엑셀 데이터 불러와 데이터 프레임 생성

folder_dir = 'C:/data\실습데이터/2024_2'
DATA_FILE =   "stock_basic.xlsx"

dff = pd.read_excel(folder_dir + "/" + DATA_FILE, 'stock_basic') 
print(dff.head(5))
dff.shape
# Out:
#   company_code company_name  fiscal_year         sales  operating_income  \
# 0      A000100         유한양행         2021   1687.810318         48.596120
# 1      A000100         유한양행         2022   1775.846943         36.028967
# 2      A000100         유한양행         2023   1858.983760         56.759795
# 3      A000270           기아         2021  69862.366000       5065.685000
# 4      A000270           기아         2022  86559.029000       7233.120000
#
#     net_income  debt_ratio  listed_date sector_name
# 0    99.126678       27.27     19621101         의약품
# 1    90.592526       23.16     19621101         의약품
# 2   134.031517       33.89     19621101         의약품
# 3  4760.311000       91.48     19730721        운수장비
# 4  5408.976000       87.35     19730721        운수장비
# (300, 9)

# %%
# 2. DB 에 테이블 생성

dff.to_sql('stock_bs', con=engine, index=False,if_exists='replace') # append
# Out:
# 300

# %%
# 3. DB 에서 테이블 가져오기

dffs=pd.read_sql_table('stock_bs', con=engine)

# %%
dffs
# Out:
#     company_code company_name  fiscal_year         sales  operating_income  \
# 0        A000100         유한양행         2021   1687.810318         48.596120
# 1        A000100         유한양행         2022   1775.846943         36.028967
# 2        A000100         유한양행         2023   1858.983760         56.759795
# 3        A000270           기아         2021  69862.366000       5065.685000
# 4        A000270           기아         2022  86559.029000       7233.120000
# ..           ...          ...          ...           ...               ...
# 295      A450080       에코프로머티         2022    665.248279         38.988204
# 296      A450080       에코프로머티         2023    952.523316          8.772772
# 297      A454910       두산로보틱스         2021     36.980223         -7.084713
# 298      A454910       두산로보틱스         2022     44.953674        -13.228333
# 299      A454910       두산로보틱스         2023     53.038372        -19.167550
#
#       net_income  debt_ratio  listed_date sector_name
# 0      99.126678       27.27     19621101         의약품
# 1      90.592526       23.16     19621101         의약품
# 2     134.031517       33.89     19621101         의약품
# 3    4760.311000       91.48     19730721        운수장비
# 4    5408.976000       87.35     19730721        운수장비
# ..           ...         ...          ...         ...
# 295    15.582712      102.01     20231117          기타
# 296     5.045160       38.19     20231117          기타
# 297    -7.417406       89.94     20231005          기계
# 298   -12.548180       46.42     20231005          기계
# 299   -15.873539        4.01     20231005          기계
#
# [300 rows x 9 columns]

# %%
# 4. example DB에서 stock_bs table 가져오기

query = '''select  * from stock_bs'''
stock_bs = pd.read_sql(query, con=engine)
engine.dispose()  

display(stock_bs)
# Out:
#     company_code company_name  fiscal_year         sales  operating_income  \
# 0        A000100         유한양행         2021   1687.810318         48.596120
# 1        A000100         유한양행         2022   1775.846943         36.028967
# 2        A000100         유한양행         2023   1858.983760         56.759795
# 3        A000270           기아         2021  69862.366000       5065.685000
# 4        A000270           기아         2022  86559.029000       7233.120000
# ..           ...          ...          ...           ...               ...
# 295      A450080       에코프로머티         2022    665.248279         38.988204
# 296      A450080       에코프로머티         2023    952.523316          8.772772
# 297      A454910       두산로보틱스         2021     36.980223         -7.084713
# 298      A454910       두산로보틱스         2022     44.953674        -13.228333
# 299      A454910       두산로보틱스         2023     53.038372        -19.167550
#
#       net_income  debt_ratio  listed_date sector_name
# 0      99.126678       27.27     19621101         의약품
# 1      90.592526       23.16     19621101         의약품
# 2     134.031517       33.89     19621101         의약품
# 3    4760.311000       91.48     19730721        운수장비
# 4    5408.976000       87.35     19730721        운수장비
# ..           ...         ...          ...         ...
# 295    15.582712      102.01     20231117          기타
# 296     5.045160       38.19     20231117          기타
# 297    -7.417406       89.94     20231005          기계
# 298   -12.548180       46.42     20231005          기계
# 299   -15.873539        4.01     20231005          기계
#
# [300 rows x 9 columns]

# %%
#  DB 변경하여  테이블 불러오기:    stock_db에서 stock_basic table 가져오기

engine = create_engine('mysql+pymysql://root:1234@127.0.0.1:3306/stock_db') 
query = '''select  * from krx300_fin'''
stock_bb = pd.read_sql(query, con=engine)
engine.dispose()  
display(stock_bb)
# Out:
#      jong_code jong_name  fm    fy  period            asset     liabilities  \
# 0       005930      삼성전자  12  2014  Annual  230,422,958,000  62,334,770,000
# 1       005930      삼성전자  12  2015  Annual  242,179,521,000  63,119,716,000
# 2       005930      삼성전자  12  2016  Annual  262,174,324,000  69,211,291,000
# 3       005930      삼성전자  12  2017  Annual  301,752,090,000  87,260,662,000
# 4       005930      삼성전자  12  2018  Annual  339,357,244,000  91,604,067,000
# ...        ...       ...  ..   ...     ...              ...             ...
# 3005    487570      HS효성  12  2019  Annual
# 3006    487570      HS효성  12  2020  Annual
# 3007    487570      HS효성  12  2021  Annual
# 3008    487570      HS효성  12  2022  Annual
# 3009    487570      HS효성  12  2023  Annual
#
#         total_capital            sales operating_profit      net_income  \
# 0     168,088,188,000  206,205,987,000   25,025,071,000  23,394,358,000
# 1     179,059,805,000  200,653,482,000   26,413,442,000  19,060,144,000
# 2     192,963,033,000  201,866,745,000   29,240,672,000  22,726,092,000
# 3     214,491,428,000  239,575,376,000   53,645,038,000  42,186,747,000
# 4     247,753,177,000  243,771,415,000   58,886,669,000  44,344,857,000
# ...               ...              ...              ...             ...
# 3005
# 3006
# 3007
# 3008
# 3009
#
#             cashflow      dividends    DPS    EPS     BPS     SPS   CFPS  \
# 0     41,135,920,000  2,999,972,377    400  2,713  20,056  24,241  4,836
# 1     39,625,485,000  3,068,737,397    420  2,198  21,903  23,588  4,658
# 2     43,128,620,000  3,991,891,755    570  2,735  24,340  24,632  5,263
# 3     63,461,961,000  5,826,302,126    850  5,421  28,971  31,414  8,321
# 4     70,372,914,000  9,619,242,546  1,416  6,024  35,342  33,458  9,659
# ...              ...            ...    ...    ...     ...     ...    ...
# 3005
# 3006
# 3007
# 3008
# 3009
#
#      EBITDAPS
# 0       5,064
# 1       5,566
# 2       6,095
# 3       9,934
# 4      11,717
# ...       ...
# 3005
# 3006
# 3007
# 3008
# 3009
#
# [3010 rows x 19 columns]
